# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv("data/TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])
df.head()
# Out:
#    STAID   SOUID       DATE     TG   Q_TG
# 0      1   35381 1860-01-01     21      1
# 1      1   35381 1860-01-02     46      1
# 2      1   35381 1860-01-03     31      1
# 3      1   35381 1860-01-04     37      1
# 4      1   35381 1860-01-05     31      1

# %%
df.loc[df['   TG'] != -9999]['   TG'].hist()
# Out:
# <AxesSubplot: >

# %%
df.loc[df['    DATE'] == "1860-01-04"]['   TG'].squeeze() / 10
# Out:
# 3.7

# %%
df.loc[df['   TG']== df['   TG'].max()]['    DATE'].squeeze()
# Out:
# Timestamp('1868-08-16 00:00:00')

# %% [markdown]
# # Calculate new column

# %%
import numpy as np
df['TGB'] = df['   TG'].mask(df['   TG']==-9999, np.nan)
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG  Fahenheit  Fahrenheit  \
# 0          1   35381 1860-01-01     21      1  2.1      35.78       35.78
# 1          1   35381 1860-01-02     46      1  4.6      40.28       40.28
# 2          1   35381 1860-01-03     31      1  3.1      37.58       37.58
# 3          1   35381 1860-01-04     37      1  3.7      38.66       38.66
# 4          1   35381 1860-01-05     31      1  3.1      37.58       37.58
# ...      ...     ...        ...    ...    ...  ...        ...         ...
# 59469      1   35381 2022-10-27  -9999      9  NaN   -1767.82         NaN
# 59470      1   35381 2022-10-28  -9999      9  NaN   -1767.82         NaN
# 59471      1   35381 2022-10-29  -9999      9  NaN   -1767.82         NaN
# 59472      1   35381 2022-10-30  -9999      9  NaN   -1767.82         NaN
# 59473      1   35381 2022-10-31  -9999      9  NaN   -1767.82         NaN
#
#         TGB
# 0      21.0
# 1      46.0
# 2      31.0
# 3      37.0
# 4      31.0
# ...     ...
# 59469   NaN
# 59470   NaN
# 59471   NaN
# 59472   NaN
# 59473   NaN
#
# [59474 rows x 9 columns]

# %%
df["TG"] = df['TGB'] / 10
df['Fahrenheit'] = df["TG"] * 9/5 +32
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG  Fahenheit  Fahrenheit  \
# 0          1   35381 1860-01-01     21      1  2.1      35.78       35.78
# 1          1   35381 1860-01-02     46      1  4.6      40.28       40.28
# 2          1   35381 1860-01-03     31      1  3.1      37.58       37.58
# 3          1   35381 1860-01-04     37      1  3.7      38.66       38.66
# 4          1   35381 1860-01-05     31      1  3.1      37.58       37.58
# ...      ...     ...        ...    ...    ...  ...        ...         ...
# 59469      1   35381 2022-10-27  -9999      9  NaN   -1767.82         NaN
# 59470      1   35381 2022-10-28  -9999      9  NaN   -1767.82         NaN
# 59471      1   35381 2022-10-29  -9999      9  NaN   -1767.82         NaN
# 59472      1   35381 2022-10-30  -9999      9  NaN   -1767.82         NaN
# 59473      1   35381 2022-10-31  -9999      9  NaN   -1767.82         NaN
#
#         TGB
# 0      21.0
# 1      46.0
# 2      31.0
# 3      37.0
# 4      31.0
# ...     ...
# 59469   NaN
# 59470   NaN
# 59471   NaN
# 59472   NaN
# 59473   NaN
#
# [59474 rows x 9 columns]

# %% [markdown]
# # Plotting

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG', 'TG', 'Fahenheit',
#        'Fahrenheit', 'TGB'],
#       dtype='object')

# %%
df.plot(x='    DATE', y='TG', figsize=(15,3))
# Out:
# <AxesSubplot: xlabel='    DATE'>
